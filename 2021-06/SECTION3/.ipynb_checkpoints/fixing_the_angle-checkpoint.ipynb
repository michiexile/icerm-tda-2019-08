# %%
# %pylab inline
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
eg = 'Example1_d=0.5'
points = np.loadtxt(eg+'.txt')
theta = [2*pi-arccos(x/norm([x,y], ord=2)) if arcsin(y/norm([x,y], ord=2))<0 else arccos(x/norm([x,y], ord=2)) for x,y in points]
for l in ['0','0.5','1']:
    gcc = np.loadtxt(eg+'_CircularCoordinates_'+l+'_0.txt')
    figure(figsize=(5,5),dpi=100)
    scatter(theta,gcc,c='b',s=10)
    savefig(eg+'-'+l+'.pdf',format='pdf')

# %%
eg = 'Example1_d=1.5'
points = np.loadtxt(eg+'.txt')
theta = [2*pi-arccos(x/norm([x,y], ord=2)) if arcsin(y/norm([x,y], ord=2))<0 else arccos(x/norm([x,y], ord=2)) for x,y in points]
for l in ['0','0.5','1']:
    gcc = np.loadtxt(eg+'_CircularCoordinates_'+l+'_0.txt')
    figure(figsize=(5,5),dpi=100)
    scatter(theta,gcc,c='b',s=10)
    savefig(eg+'-'+l+'.pdf',format='pdf')

# %%
eg = np.loadtxt('Example1_d=1.txt')
points = np.loadtxt(eg+'.txt')
theta = [2*pi-arccos(x/norm([x,y], ord=2)) if arcsin(y/norm([x,y], ord=2))<0 else arccos(x/norm([x,y], ord=2)) for x,y in points]
for l in ['0','0.5','1']:
    gcc = np.loadtxt(eg+'_CircularCoordinates_'+l+'_0.txt')
    figure(figsize=(5,5),dpi=100)
    scatter(theta,gcc,c='b',s=10)
    savefig(eg+'-'+l+'.pdf',format='pdf')

# %%
points = np.loadtxt('Example1_d=2.0.txt')
points = np.loadtxt(eg+'.txt')
theta = [2*pi-arccos(x/norm([x,y], ord=2)) if arcsin(y/norm([x,y], ord=2))<0 else arccos(x/norm([x,y], ord=2)) for x,y in points]
for l in ['0','0.5','1']:
    gcc = np.loadtxt(eg+'_CircularCoordinates_'+l+'_0.txt')
    figure(figsize=(5,5),dpi=100)
    scatter(theta,gcc,c='b',s=10)
    savefig(eg+'-'+l+'.pdf',format='pdf')

# %%
points = np.loadtxt('Example1_d=7.5.txt')
points = np.loadtxt(eg+'.txt')
theta = [2*pi-arccos(x/norm([x,y], ord=2)) if arcsin(y/norm([x,y], ord=2))<0 else arccos(x/norm([x,y], ord=2)) for x,y in points]
for l in ['0','0.5','1']:
    gcc = np.loadtxt(eg+'_CircularCoordinates_'+l+'_0.txt')
    figure(figsize=(5,5),dpi=100)
    scatter(theta,gcc,c='b',s=10)
    savefig(eg+'-'+l+'.pdf',format='pdf')

# %%
eg = 'Example1_d=7.5'
points = np.loadtxt(eg+'.txt')
theta = [2*pi-arccos(x/norm([x,y], ord=2)) if arcsin(y/norm([x,y], ord=2))<0 else arccos(x/norm([x,y], ord=2)) for x,y in points]
for l in ['0','0.5','1']:
    gcc = np.loadtxt(eg+'_CircularCoordinates_'+l+'_0.txt')
    figure(figsize=(5,5),dpi=100)
    scatter(theta,gcc,c='b',s=10)
    savefig(eg+'-'+l+'.pdf',format='pdf')

# %%
Example1_J .cmd
10 days ago51 B
Example1_J.txt
10 days ago15.6 kB
Example1_J_CircularCoordinates_0.5_0.txt
10 days ago7.8 kB
Example1_J_CircularCoordinates_0_0.txt
10 days ago7.8 kB
Example1_J_CircularCoordinates_1_0.txt
10 days ago7.8 kB
Example1_J_Embedding_0.5.txt
10 days ago15.2 kB
Example1_J_Embedding_0.txt
10 days ago15.2 kB
Example1_J_Embedding_1.txt
10 days ago15.2 kB
Example1_J_output.pdf
10 days ago183 kB
Example2.cmd
11 days ago51 B
Example2.txt
11 days ago10.4 kB
Example2_CircularCoordinates_0.5_0.txt
11 days ago5.2 kB
Example2_CircularCoordinates_0.5_1.txt
11 days ago5.2 kB
Example2_CircularCoordinates_0_0.txt
11 days ago5.2 kB
Example2_CircularCoordinates_0_1.txt
11 days ago5.2 kB
Example2_CircularCoordinates_1_0.txt
11 days ago5.2 kB
Example2_CircularCoordinates_1_1.txt
11 days ago5.2 kB
Example2_Embedding_0.5.txt
11 days ago20.3 kB
Example2_Embedding_0.txt
11 days ago20.2 kB
Example2_Embedding_1.txt
11 days ago20.3 kB
Example2_J.cmd
10 days ago51 B
Example2_J.txt
10 days ago10.4 kB
Example2_J_CircularCoordinates_0.5_0.txt
10 days ago5.2 kB
Example2_J_CircularCoordinates_0.5_1.txt
10 days ago5.2 kB
Example2_J_CircularCoordinates_0_0.txt
10 days ago5.2 kB
Example2_J_CircularCoordinates_0_1.txt
10 days ago5.2 kB
Example2_J_CircularCoordinates_1_0.txt
10 days ago5.2 kB
Example2_J_CircularCoordinates_1_1.txt
10 days ago5.2 kB
Example2_J_Embedding_0.5.txt
10 days ago20.4 kB
Example2_J_Embedding_0.txt
10 days ago20.4 kB
Example2_J_Embedding_1.txt
10 days ago20.4 kB
Example2_J_output.pdf
10 days ago218 kB
Example2_output.pdf
11 days ago217 kB
Example_pinched__torus.cmd
11 days ago63 B
Example_pinched__torus.txt
11 days ago23.3 kB
Example_pinched__torus_CircularCoordinates_0.5_0.txt
11 days ago7.8 kB
Example_pinched__torus_CircularCoordinates_0_0.txt
11 days ago7.8 kB
Example_pinched__torus_CircularCoordinates_1_0.txt
11 days ago7.8 kB
Example_pinched__torus_Embedding_0.5.txt
11 days ago15.2 kB
Example_pinched__torus_Embedding_0.txt
11 days ago15.2 kB
Example_pinched__torus_Embedding_1.txt
11 days ago15.3 kB
Example_pinched__torus_J.cmd
10 days ago121 B
Example_pinched__torus_J.txt
10 days ago23.2 kB
Example_pinched__torus_J.txt.txt
10 days ago23.2 kB
Example_pinched__torus_J_CircularCoordinates_0.5_0.txt
10 days ago7.8 kB
Example_pinched__torus_J_CircularCoordinates_0_0.txt
10 days ago7.8 kB
Example_pinched__torus_J_CircularCoordinates_1_0.txt
10 days ago7.8 kB
Example_pinched__torus_J_Embedding_0.5.txt
10 days ago15.1 kB
Example_pinched__torus_J_Embedding_0.txt
10 days ago15.1 kB
Example_pinched__torus_J_Embedding_1.txt
10 days ago15.3 kB
Example_pinched__torus_J_output.pdf
10 days ago184 kB
Example_pinched__torus_output.pdf
